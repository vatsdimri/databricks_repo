# %% [markdown]
# # MLFlow

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, roc_auc_score
from xgboost import XGBClassifier

import mlflow

# %%
mlflow.set_experiment("/Users/vatdimri1995@gmail.com/heart_disease_detection")

# %%
train_data = spark.read.csv("/Workspace/Users/vatdimri1995@gmail.com/machine_learning/kaggle_problems/train.csv")
test_data = spark.read.csv("/Workspace/Users/vatdimri1995@gmail.com/machine_learning/kaggle_problems/test.csv")
# train_data.write.saveAsTable("train_data")
# test_data.write.saveAsTable("test_data")
sample_sub = pd.read_csv("/Workspace/Users/vatdimri1995@gmail.com/machine_learning/kaggle_problems/sample_submission.csv")
